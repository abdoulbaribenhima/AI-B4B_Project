# %%
import pandas as pd
import numpy as np

import pycountry

# %%
df=pd.read_csv(r".\Data\Sanctions_Data_Merged.csv")

df.head()
# Out:
# C:\Users\abdou\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0                  id        schema                   name  \
# 0           0  arpet-entidades-13  Organization            VALUMAR LLC
# 1           1   arpet-personas-10        Person      Hadi Soleimanpour
# 2           2   arpet-personas-11        Person         Alí Fallahijan
# 3           3   arpet-personas-15        Person     Ahmad Reza Asghari
# 4           4   arpet-personas-19        Person  hussein mohamed jomma
#
#   aliases             birth_date countries addresses           identifiers  \
# 0     NaN                    NaN       NaN       NaN                   NaN
# 1     NaN  1956-01-13;1960-08-24        ir       NaN  0006686;008589;10720
# 2     NaN                   1994        ir       NaN                   NaN
# ...

# %%
countries = df["countries"]
countries
# Out:
# 0         NaN
# 1          ir
# 2          ir
# 3          ir
# 4         NaN
#          ...
# 369017     ng
# 369018     cn
# 369019     ky
# 369020     gb
# 369021     bf
# Name: countries, Length: 369022, dtype: object

# %%
countries = countries.replace(np.nan,"Unknown")
countries
# Out:
# 0         Unknown
# 1              ir
# 2              ir
# 3              ir
# 4         Unknown
#            ...
# 369017         ng
# 369018         cn
# 369019         ky
# 369020         gb
# 369021         bf
# Name: countries, Length: 369022, dtype: object

# %%
newList = []
for i in countries:
    newList.append(i.split(';'))
newList
# Out:
# [['Unknown'],
#  ['ir'],
#  ['ir'],
#  ['ir'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['ru'],
#  ['it'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['rs'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
# ...

# %%
# mylist = [i.split(';') for i in countries] 
# mylist

# %%
newList = []
for i in countries:
    newList.append(i.split(';'))
newList
# Out:
# [['Unknown'],
#  ['ir'],
#  ['ir'],
#  ['ir'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['ru'],
#  ['it'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['rs'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['rs'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
#  ['Unknown'],
# ...

# %%
countries = newList

# %%
# Source: Flatten List of Lists Using Nested for Loops
# https://stackabuse.com/python-how-to-flatten-list-of-lists/
def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
countries = flatten_list(countries)
countries
# Out:
# ['Unknown',
#  'ir',
#  'ir',
#  'ir',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'ru',
#  'it',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'rs',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'rs',
#  'rs',
#  'rs',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'rs',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'rs',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'rs',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
#  'Unknown',
# ...

# %%
# Source: How to get unique values in a list in python
# https://moonbooks.org/Articles/How-to-get-unique-values-in-a-list-in-python-/
countries = np.array(countries)
countries
# Out:
# array(['Unknown', 'ir', 'ir', ..., 'ky', 'gb', 'bf'], dtype='<U7')

# %%
countries = np.unique(countries)
countries
# Out:
# array(['Unknown', 'ad', 'ae', 'af', 'ag', 'ai', 'al', 'am', 'ao', 'ar',
#        'as', 'at', 'au', 'aw', 'ax', 'az', 'az-nk', 'ba', 'bb', 'bd',
#        'be', 'bf', 'bg', 'bh', 'bi', 'bj', 'bl', 'bm', 'bn', 'bo', 'br',
#        'bs', 'bt', 'bw', 'by', 'bz', 'ca', 'cd', 'cf', 'cg', 'ch', 'ci',
#        'ck', 'cl', 'cm', 'cn', 'cn-xz', 'co', 'cr', 'cshh', 'csxx', 'cu',
#        'cv', 'cw', 'cy', 'cy-trnc', 'cz', 'dd', 'de', 'dj', 'dk', 'dm',
#        'do', 'dz', 'ec', 'ee', 'eg', 'eh', 'er', 'es', 'et', 'eu', 'fi',
#        'fj', 'fk', 'fm', 'fo', 'fr', 'ga', 'gb', 'gb-nir', 'gb-sct',
#        'gb-wls', 'gd', 'ge', 'ge-ab', 'gg', 'gg-srk', 'gh', 'gi', 'gl',
#        'gm', 'gn', 'gq', 'gr', 'gt', 'gu', 'gw', 'gy', 'hk', 'hn', 'hr',
#        'ht', 'hu', 'id', 'ie', 'il', 'im', 'in', 'iq', 'ir', 'is', 'it',
#        'je', 'jm', 'jo', 'jp', 'ke', 'kg', 'kh', 'ki', 'km', 'kn', 'kp',
#        'kr', 'kw', 'ky', 'kz', 'la', 'lb', 'lc', 'li', 'lk', 'lr', 'ls',
# ...

# %%
countries = list(countries)
countries
# Out:
# ['Unknown',
#  'ad',
#  'ae',
#  'af',
#  'ag',
#  'ai',
#  'al',
#  'am',
#  'ao',
#  'ar',
#  'as',
#  'at',
#  'au',
#  'aw',
#  'ax',
#  'az',
#  'az-nk',
#  'ba',
#  'bb',
#  'bd',
#  'be',
#  'bf',
#  'bg',
#  'bh',
#  'bi',
#  'bj',
#  'bl',
#  'bm',
#  'bn',
#  'bo',
#  'br',
#  'bs',
#  'bt',
#  'bw',
#  'by',
#  'bz',
#  'ca',
#  'cd',
#  'cf',
#  'cg',
#  'ch',
#  'ci',
#  'ck',
#  'cl',
#  'cm',
#  'cn',
#  'cn-xz',
#  'co',
#  'cr',
#  'cshh',
#  'csxx',
#  'cu',
#  'cv',
#  'cw',
#  'cy',
#  'cy-trnc',
#  'cz',
#  'dd',
#  'de',
#  'dj',
#  'dk',
#  'dm',
#  'do',
#  'dz',
#  'ec',
#  'ee',
#  'eg',
#  'eh',
#  'er',
#  'es',
#  'et',
#  'eu',
#  'fi',
#  'fj',
#  'fk',
#  'fm',
#  'fo',
#  'fr',
#  'ga',
#  'gb',
#  'gb-nir',
#  'gb-sct',
#  'gb-wls',
#  'gd',
#  'ge',
#  'ge-ab',
#  'gg',
#  'gg-srk',
#  'gh',
#  'gi',
#  'gl',
#  'gm',
#  'gn',
#  'gq',
#  'gr',
#  'gt',
#  'gu',
#  'gw',
#  'gy',
#  'hk',
#  'hn',
#  'hr',
#  'ht',
#  'hu',
#  'id',
#  'ie',
# ...

# %%
countries = [countries.upper() for countries in countries]
countries
# Out:
# ['UNKNOWN',
#  'AD',
#  'AE',
#  'AF',
#  'AG',
#  'AI',
#  'AL',
#  'AM',
#  'AO',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AW',
#  'AX',
#  'AZ',
#  'AZ-NK',
#  'BA',
#  'BB',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
#  'BH',
#  'BI',
#  'BJ',
#  'BL',
#  'BM',
#  'BN',
#  'BO',
#  'BR',
#  'BS',
#  'BT',
#  'BW',
#  'BY',
#  'BZ',
#  'CA',
#  'CD',
#  'CF',
#  'CG',
#  'CH',
#  'CI',
#  'CK',
#  'CL',
#  'CM',
#  'CN',
#  'CN-XZ',
#  'CO',
#  'CR',
#  'CSHH',
#  'CSXX',
#  'CU',
#  'CV',
#  'CW',
#  'CY',
#  'CY-TRNC',
#  'CZ',
#  'DD',
#  'DE',
#  'DJ',
#  'DK',
#  'DM',
#  'DO',
#  'DZ',
#  'EC',
#  'EE',
#  'EG',
#  'EH',
#  'ER',
#  'ES',
#  'ET',
#  'EU',
#  'FI',
#  'FJ',
#  'FK',
#  'FM',
#  'FO',
#  'FR',
#  'GA',
#  'GB',
#  'GB-NIR',
#  'GB-SCT',
#  'GB-WLS',
#  'GD',
#  'GE',
#  'GE-AB',
#  'GG',
#  'GG-SRK',
#  'GH',
#  'GI',
#  'GL',
#  'GM',
#  'GN',
#  'GQ',
#  'GR',
#  'GT',
#  'GU',
#  'GW',
#  'GY',
#  'HK',
#  'HN',
#  'HR',
#  'HT',
#  'HU',
#  'ID',
#  'IE',
# ...

# %%
len(countries)
# Out:
# 254

# %%
from pandas import DataFrame

country = DataFrame (countries,columns=['Country'])
country
# Out:
#      Country
# 0    UNKNOWN
# 1         AD
# 2         AE
# 3         AF
# 4         AG
# ..       ...
# 249       YE
# 250     YUCS
# 251       ZA
# 252       ZM
# 253       ZW
#
# [254 rows x 1 columns]

# %%
country ["ISO_CODE"] = pd.NaT
country
# Out:
#      Country ISO_CODE
# 0    UNKNOWN      NaT
# 1         AD      NaT
# 2         AE      NaT
# 3         AF      NaT
# 4         AG      NaT
# ..       ...      ...
# 249       YE      NaT
# 250     YUCS      NaT
# 251       ZA      NaT
# 252       ZM      NaT
# 253       ZW      NaT
#
# [254 rows x 2 columns]

# %%
codes=[]
code=[]
countries = {}

for country in pycountry.countries:
    countries[country.alpha_2] = country.numeric
    
countries
# Out:
# {'AW': '533',
#  'AF': '004',
#  'AO': '024',
#  'AI': '660',
#  'AX': '248',
#  'AL': '008',
#  'AD': '020',
#  'AE': '784',
#  'AR': '032',
#  'AM': '051',
#  'AS': '016',
#  'AQ': '010',
#  'TF': '260',
#  'AG': '028',
#  'AU': '036',
#  'AT': '040',
#  'AZ': '031',
#  'BI': '108',
#  'BE': '056',
#  'BJ': '204',
#  'BQ': '535',
#  'BF': '854',
#  'BD': '050',
#  'BG': '100',
#  'BH': '048',
#  'BS': '044',
#  'BA': '070',
#  'BL': '652',
#  'BY': '112',
#  'BZ': '084',
#  'BM': '060',
#  'BO': '068',
#  'BR': '076',
#  'BB': '052',
#  'BN': '096',
#  'BT': '064',
#  'BV': '074',
#  'BW': '072',
#  'CF': '140',
#  'CA': '124',
#  'CC': '166',
#  'CH': '756',
#  'CL': '152',
#  'CN': '156',
#  'CI': '384',
#  'CM': '120',
#  'CD': '180',
#  'CG': '178',
#  'CK': '184',
#  'CO': '170',
#  'KM': '174',
#  'CV': '132',
#  'CR': '188',
#  'CU': '192',
#  'CW': '531',
#  'CX': '162',
#  'KY': '136',
#  'CY': '196',
#  'CZ': '203',
#  'DE': '276',
#  'DJ': '262',
#  'DM': '212',
# ...

# %%
sanc_countries = pd.Series(countries, name='ISO_CODE')

# %%
sanc_countries.index.name = 'Country'

# %%
sanc_countries = sanc_countries.reset_index()
sanc_countries
# Out:
#     Country ISO_CODE
# 0        AW      533
# 1        AF      004
# 2        AO      024
# 3        AI      660
# 4        AX      248
# ..      ...      ...
# 244      WS      882
# 245      YE      887
# 246      ZA      710
# 247      ZM      894
# 248      ZW      716
#
# [249 rows x 2 columns]

# %%
sanc_countries.to_csv('./Data/List_coutries+iso_code.csv', index=False)

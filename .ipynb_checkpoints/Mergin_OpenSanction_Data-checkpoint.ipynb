# %%
import pandas as pd
import glob
import os

# %%
# merging the files
files_joined = os.path.join(r'.\OpenSanction_Data\Data', "targets*.csv")

# %%
# Return a list of all joined files
list_files = glob.glob(files_joined)

# %%
list_files
# Out:
# ['C:\\Users\\abdou\\Desktop\\Sogeti\\DataSet-OpenSanctions\\targets.Consolidated_Sanctioned_Entities.csv',
#  'C:\\Users\\abdou\\Desktop\\Sogeti\\DataSet-OpenSanctions\\targets.Due_Diligence_List.csv',
#  'C:\\Users\\abdou\\Desktop\\Sogeti\\DataSet-OpenSanctions\\targets.Politically_Exposed_Persons.csv',
#  'C:\\Users\\abdou\\Desktop\\Sogeti\\DataSet-OpenSanctions\\targets.Warrants_and_Criminal_Entities.csv']

# %%
print("** Merging multiple csv files into a single pandas dataframe **")
# Merging files by joining all files
sanction = pd.concat(map(pd.read_csv, list_files), ignore_index=True)
print(sanction)
# Out:
# ** Merging multiple csv files into a single pandas dataframe **
#                         id        schema                               name  \
# 0       arpet-entidades-13  Organization                        VALUMAR LLC
# 1        arpet-entidades-8  Organization  SLAMIC STATE WEST AFRICA PROVINCE
# 2        arpet-personas-10        Person                  Hadi Soleimanpour
# 3        arpet-personas-11        Person                     Alí Fallahijan
# 4        arpet-personas-15        Person                 Ahmad Reza Asghari
# ...                    ...           ...                                ...
# 367391        wbdeb-646876   LegalEntity         EXPRESS AUTOMATION LIMITED
# 367392        wbdeb-646878   LegalEntity       MACTEBAC CONTRACTORS LIMITED
# 367393        wbdeb-646879   LegalEntity             MR. JORAM OPALA OTIENO
# 367394         wbdeb-68368   LegalEntity              RIBALCO INTERNATIONAL
# 367395         wbdeb-83317   LegalEntity                       SEYDOU IDANI
#
#        aliases             birth_date countries  \
# 0          NaN                    NaN       NaN
# 1          NaN                    NaN       NaN
# 2          NaN  1956-01-13;1960-08-24        ir
# 3          NaN                   1994        ir
# 4          NaN             1961-06-11        ir
# ...        ...                    ...       ...
# 367391     NaN                    NaN        ke
# 367392     NaN                    NaN        ke
# 367393     NaN                    NaN        ke
# 367394     NaN                    NaN        gb
# 367395     NaN                    NaN        bf
#
#                                                 addresses  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 367391  4TH FLOOR, DELTA CORNER ANNEX,P.O. BOX 22709-0...
# 367392  CBD, SUNA BUILDING, SIRARE ROAD EAST/WESWETA 1...
# 367393  CBD, SUNA BUILDING, SIRARE ROAD EAST/WESWETA 1...
# 367394                                          BERKSHIRE
# 367395                                                NaN
#
#                  identifiers  \
# 0                        NaN
# 1                        NaN
# 2       0006686;008589;10720
# 3                        NaN
# 4                     008664
# ...                      ...
# 367391                   NaN
# 367392                   NaN
# 367393                   NaN
# 367394                   NaN
# 367395                   NaN
#
#                                                 sanctions phones emails  \
# 0       Unidad de Información Financiera - ARG List - ...    NaN    NaN
# 1             Unidad de Información Financiera - ARG List    NaN    NaN
# 2             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# 3             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# 4             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# ...                                                   ...    ...    ...
# 367391    Cross Debarment: AfDB - 2022-03-01 - 2024-08-17    NaN    NaN
# 367392    Cross Debarment: AfDB - 2022-03-01 - 2023-12-14    NaN    NaN
# 367393    Cross Debarment: AfDB - 2022-03-01 - 2023-12-14    NaN    NaN
# 367394  Procurement Guidelines 1.15(a)(i) & (ii) - 200...    NaN    NaN
# 367395  Consultant Guidelines 1.25(a)(i) - 2004-10-25 ...    NaN    NaN
#
#                              dataset            last_seen           first_seen
# 0                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 1                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 2                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 3                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 4                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# ...                              ...                  ...                  ...
# 367391  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367392  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367393  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367394  WorldBank Debarred Providers  2021-07-26 11:55:45  2022-03-03 06:18:24
# 367395  WorldBank Debarred Providers  2021-07-26 11:55:45  2022-03-03 06:18:24
#
# [367396 rows x 14 columns]
# C:\Users\abdou\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (6,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(

# %%
sanction
# Out:
#                         id        schema                               name  \
# 0       arpet-entidades-13  Organization                        VALUMAR LLC
# 1        arpet-entidades-8  Organization  SLAMIC STATE WEST AFRICA PROVINCE
# 2        arpet-personas-10        Person                  Hadi Soleimanpour
# 3        arpet-personas-11        Person                     Alí Fallahijan
# 4        arpet-personas-15        Person                 Ahmad Reza Asghari
# ...                    ...           ...                                ...
# 367391        wbdeb-646876   LegalEntity         EXPRESS AUTOMATION LIMITED
# 367392        wbdeb-646878   LegalEntity       MACTEBAC CONTRACTORS LIMITED
# 367393        wbdeb-646879   LegalEntity             MR. JORAM OPALA OTIENO
# 367394         wbdeb-68368   LegalEntity              RIBALCO INTERNATIONAL
# 367395         wbdeb-83317   LegalEntity                       SEYDOU IDANI
#
#        aliases             birth_date countries  \
# 0          NaN                    NaN       NaN
# 1          NaN                    NaN       NaN
# 2          NaN  1956-01-13;1960-08-24        ir
# 3          NaN                   1994        ir
# 4          NaN             1961-06-11        ir
# ...        ...                    ...       ...
# 367391     NaN                    NaN        ke
# 367392     NaN                    NaN        ke
# 367393     NaN                    NaN        ke
# 367394     NaN                    NaN        gb
# 367395     NaN                    NaN        bf
#
#                                                 addresses  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 367391  4TH FLOOR, DELTA CORNER ANNEX,P.O. BOX 22709-0...
# 367392  CBD, SUNA BUILDING, SIRARE ROAD EAST/WESWETA 1...
# 367393  CBD, SUNA BUILDING, SIRARE ROAD EAST/WESWETA 1...
# 367394                                          BERKSHIRE
# 367395                                                NaN
#
#                  identifiers  \
# 0                        NaN
# 1                        NaN
# 2       0006686;008589;10720
# 3                        NaN
# 4                     008664
# ...                      ...
# 367391                   NaN
# 367392                   NaN
# 367393                   NaN
# 367394                   NaN
# 367395                   NaN
#
#                                                 sanctions phones emails  \
# 0       Unidad de Información Financiera - ARG List - ...    NaN    NaN
# 1             Unidad de Información Financiera - ARG List    NaN    NaN
# 2             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# 3             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# 4             ARG List - UFI AMIA - UFI AMIA - 2019-07-26    NaN    NaN
# ...                                                   ...    ...    ...
# 367391    Cross Debarment: AfDB - 2022-03-01 - 2024-08-17    NaN    NaN
# 367392    Cross Debarment: AfDB - 2022-03-01 - 2023-12-14    NaN    NaN
# 367393    Cross Debarment: AfDB - 2022-03-01 - 2023-12-14    NaN    NaN
# 367394  Procurement Guidelines 1.15(a)(i) & (ii) - 200...    NaN    NaN
# 367395  Consultant Guidelines 1.25(a)(i) - 2004-10-25 ...    NaN    NaN
#
#                              dataset            last_seen           first_seen
# 0                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 1                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 2                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 3                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# 4                    Argentine RePET  2022-02-10 02:00:22  2022-03-02 12:22:55
# ...                              ...                  ...                  ...
# 367391  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367392  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367393  WorldBank Debarred Providers  2022-03-02 05:14:42  2022-03-03 06:18:24
# 367394  WorldBank Debarred Providers  2021-07-26 11:55:45  2022-03-03 06:18:24
# 367395  WorldBank Debarred Providers  2021-07-26 11:55:45  2022-03-03 06:18:24
#
# [367396 rows x 14 columns]

# %%
#Saving into a CSV file
sanction.to_csv(r'.\sanction_data.csv')
